# %% [markdown]
# <h1>MTH 229 final  exam</h1>

# %% [markdown]
# <p>This is a timed test. You are expected  to  finish it  and   email me your answers by  2:15PM.</p>

# %% [markdown]
# <p>You are expected to use binder to do   your work.  If you  want,  you could   download this notebook and use it within  your own Julia, as  some of you  are  running.</p>

# %% [markdown]
# <p>To  print the entire test at once, in the menu at the upper left is "<code>File &gt; Print Preview</code>". Selecting that will create the project as a web page which you can  save as a pdf (print to pdf, say) and attach in an email to <code>jverzani@gmail.com</code>. If that  does not work, you can take  screenshots.</p>

# %% [markdown]
# <p>You <em>must</em> put your name in each cell  which  has <code>## your name here</code>. For each problem, I have left you two cells to do your work.  You can easily add additional  cells  with the  "<code>Insert &gt; Insert Cell Below</code>"  menu item. You can leave a comment by prefacing a line (or more) with hash signs:  <code>##</code>.</p>

# %% [markdown]
# <p>I set  the default graphics to be <code>gr</code>, which doesn't offer the hover effect, but will print out and won't cause issues.</p>

# %% [markdown]
# <p>During the exam, I will have zoom open to answer your  questions.  I will be on  mute,  unless there is some reason to not be.</p>

# %% [markdown]
# <p>You are free to use internet  resources for this exam, but please  do not communicate with others during the  exam.</p>

# %% [markdown]
# <p>The exam has one question for each of 6 projects. It will be worth 100 points, or 1/4 of  your grade.  The other exam is 1/4  and your project average is 1/2.</p>

# %%
## Run this cell *first*
using MTH229
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# <h2>Limits</h2>

# %% [markdown]
# <p>We discussed three ways to find a limit:  with a graph;  with a table (see  <code>lim</code>); and  symbolically (see  <code>limit</code>). For the following limit,  compute the limit  each of the three ways. Comment as to  its value, and whether the three ways agree or disagree (there  are technical reasons each  may fail).</p>

# %% [markdown]
# $$
# \lim_{x \rightarrow c}\frac{\pi/2-x-\cos^{-1}(x)}{x^3}
# $$

# %% [markdown]
# <p>(Don't try  <code>cos^&#40;-1&#41;&#40;x&#41;</code>, it won't work!)</p>

# %%
## your name here

# %% [markdown]
# <h2>Derivatives</h2>

# %% [markdown]
# <p>We  discussed finding  derivatives three  ways: a   numerical way with  a  forward difference  (using <code>&#40;f&#40;x&#43;h&#41;-f&#40;x&#41;&#41;/h</code>);  using automatic  derivatives, <code>f&#39;</code> does this;  and symbolically, <code>diff&#40;f&#41;</code> does this.</p>

# %% [markdown]
# <p>Let <code>f&#40;x&#41; &#61; x^x^x</code>.</p>

# %% [markdown]
# <p>Use the forward difference to <em>estimate</em> the derivative at <code>1.0</code>.</p>

# %% [markdown]
# <p>Graph <code>f&#39;</code> over a reasonable region. Is this  function <em>always</em> inreasing on its domain $(0,\infty)$?</p>

# %% [markdown]
# <p>Use  <code>diff</code> to find the derivative.</p>

# %%
## your name here

# %% [markdown]
# <h2>First and Second Derivatives</h2>

# %% [markdown]
# <p>Suppose you know $f'(x) = x\cdot (x-1)^2 \cdot (x-2)$. (e.g., <code>fp&#40;x&#41; &#61; x * &#40;x-1&#41;^2 * &#40;x-2&#41;</code>.) Use fzero to find:</p>

# %% [markdown]
# <ul>
# <li><p>the critical points</p>
# </li>
# <li><p>the inflection points</p>
# </li>
# <li><p>Use the first derivative test to characterize the critical point at $0$, if you can.</p>
# </li>
# <li><p>Use the second derivative test to charaterize the critical point at $1$, if you can.</p>
# </li>
# </ul>

# %%
## your name here

# %% [markdown]
# <h2>Newton's Method</h2>

# %% [markdown]
# <p>Along the way we learned four ways to find zero(s) of a function <code>f</code>:</p>

# %% [markdown]
# <ul>
# <li><p><code>fzero&#40;f,a,b&#41;</code> uses the bisection method, where <code>&#91;a,b&#93;</code> is a bracketing interval; </p>
# </li>
# <li><p><code>fzeros&#40;f,a,b&#41;</code> to find  all zeros  of <code>f</code> over  the interval <code>&#40;a,b&#41;</code>;</p>
# </li>
# <li><p><code>newton&#40;f,a&#41;</code>  to find a  zero using Newton's  method  starting at  <code>a</code>;  and</p>
# </li>
# <li><p><code>fzero&#40;f,a&#41;</code>  to find  a zero  starting at <code>a</code> with a more  robust algorithm than Newton's method.</p>
# </li>
# </ul>

# %% [markdown]
# <p>For this  problem, <code>f</code> is  defined and  plotted below. <strong>Run  this cell</strong>. Clearly the answer is  $0$. If you take <code>a&#61;-1</code> and <code>b&#61;1</code>, do each of the four methods find the zero? If not, say why not.</p>

# %%
function f(x)
    m,a,b = 1/4,1/10,1/8
    if x < -a
        m*x - b
    elseif x > a
        m*x + b
    else
        (m*a+b)/a * (x+a) + (-m*a -b)
    end
end
plot(f, -2, 2)
# Out:
# Plot(...)

# %%
## your name here

# %% [markdown]
# <h2>Extrema</h2>

# %% [markdown]
# <p>Consider two poles, one with height 11, the other with height 13 that sit 17 feet apart. A cable is to be attached to the top of the poles and the ground, a point <code>x</code> from  the shorter pole:</p>

# %%
plot([0,0,17,17], [11,0,0,13], linewidth=3, legend=false)
plot!([0,5,17],[11,0,13], color=:red)
# Out:
# Plot(...)

# %% [markdown]
# <p>The figure above shows <code>x&#61;5</code>, and the resulting wire has length</p>

# %%
sqrt(11^2 + 5^2) + sqrt(12^2 + 13^2)
# Out:
# 29.774851986548704

# %% [markdown]
# <p>Set up an equation for  the  length of wire for  and $0\leq x  \leq 20$.  Use julia   to find  any critical points  of your  formula. Find  the minimum length wire.</p>

# %%
## your name here

# %% [markdown]
# <h2>Integration</h2>

# %% [markdown]
# <p>As discussed, if the curve  $y=f(x)$  above  $a$ and $b$ is rotated around the $x$ axis to form  a volume, that volume will be given by the integral </p>

# %% [markdown]
# $$
# \int_a^b \pi\cdot f(x)^2 dx.
# $$

# %% [markdown]
# <p>Consider  the <code>airyai</code> function (as $f$ in the formula above) over the interval <code>&#91;0,5&#93;</code>. Rotating this around the $x$ axis gives how much volume?</p>

# %%
## your name here
