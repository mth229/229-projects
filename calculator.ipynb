# %% [markdown]
# <h1>Questions to be handed in on Julia as a calculator</h1>

# %% [markdown]
# <h3>Quick background</h3>

# %% [markdown]
# <p>Read about this material here: <a href="http://mth229.github.io/calculator.html">Julia as a calculator</a>.</p>

# %% [markdown]
# <p>For the impatient, these questions cover the use of <code>Julia</code> to replace what a calculator can do.</p>

# %% [markdown]
# <h4>The common operations on numbers: addition, subtraction,  multiplication, division, and powers.</h4>

# %% [markdown]
# <p>For the most part there is no surprise, once you learn the notations:   <code>&#43;</code>, <code>-</code>, <code>*</code>, <code>/</code>, and <code>^</code>. (Though you may find that copying and   pasting minus signs will often cause an error, as only something   that looks like a minus sign is pasted in.)</p>

# %% [markdown]
# <p>Using <code>IJulia</code>, one types the following into a cell and then presses the <em>run</em> button (or <em>shift-enter</em>):</p>

# %%
2 + 2
# Out:
# 4

# %% [markdown]
# <p>The answer follows below the cell.</p>

# %% [markdown]
# <p>Here is how one does a slightly more complicated computation:</p>

# %%
(2 + 3)^4/(5 + 6)
# Out:
# 56.81818181818182

# %% [markdown]
# <p>As with your calculator, it is very important to use parentheses, as appropriate, to circumvent the usual order of operations.</p>

# %% [markdown]
# <h4>The use of the basic families of function: trigonometric, exponential, logarithmic.</h4>

# %% [markdown]
# <p>On a calculator, there are buttons used to compute various functions. In <code>Julia</code>, there are <em>many</em> pre-defined functions that serve a similar role (later you will see how to define your own). Functions in <code>Julia</code> have names and are called using parentheses to enclose their argument(s), as with:</p>

# %%
sin(pi/4), cos(pi/3)
# Out:
# (0.7071067811865475, 0.5000000000000001)

# %% [markdown]
# <p>(With <code>IJulia</code>, when a cell is executed only the last command computed is displayed, the above shows that using a comma to separate commands on the same line can be used to get two or more commands to be displayed.)</p>

# %% [markdown]
# <p>Most basic functions in <code>Julia</code> have easy to guess names, though you will need to learn some differences, such as <code>log</code> is for $\ln$ and <code>asin</code> for $\sin^{-1}$. Function names encountered in this class include: <code>sqrt</code>, <code>cbrt</code>, <code>sin</code>, <code>cos</code>, <code>tan</code>, <code>sind</code>, <code>cosd</code>, <code>tand</code>, <code>asin</code>, <code>acos</code>, <code>atan</code>, <code>asind</code>, <code>acosd</code>, <code>atand</code>,<code>exp</code>, and <code>log</code>.</p>

# %% [markdown]
# <h4>The use of memory registers to remember intermediate values.</h4>

# %% [markdown]
# <p>Rather than have numbered memory registers, it is <em>easy</em> to assign a name to a value. For example,</p>

# %%
x = 42
# Out:
# 42

# %% [markdown]
# <p>Names can be reassigned <em>except</em> a function name can not be repurposed as a variable name later on.</p>

# %% [markdown]
# <p>For assigning more than one value at once, commas can be used as with:</p>

# %%
a,b,c = 1,2,3
# Out:
# (1, 2, 3)

# %% [markdown]
# <h4>Julia, like math, has different number types</h4>

# %% [markdown]
# <p>Unlike a calculator, but just like math, <code>Julia</code> has different types of numbers: integers, rational numbers, real numbers, and complex numbers. For the most part the distinction isn't much to worry about, but there are times where one must, such as overflow with integers. (One can only take the factorial of 20 with 64-bit integers, whereas on most calculators a factorial of 69 can be taken, but not 70.) Julia automatically assigns a type when it parses a value. a <code>1</code> will be an integer, a <code>1.0</code> an floating point number. Rational numbers are made by using two division symbols, <code>1//2</code>.</p>

# %% [markdown]
# <p>For many operations the type will be conserved, such as adding to integers. For some operations, the type will be converted, such as dividing two integer values. Mathematically, we know we can divide some integers and still get an integer, but <code>Julia</code> usually opts for the same output for its functions (and division is also a function) based on the type of the input, not the values of the input.</p>

# %% [markdown]
# <p>Okay, maybe that is too much. Let's get started.</p>

# %% [markdown]
# <h3>Expressions</h3>

# %% [markdown]
# <p>Refer to <a href="http://mth229.github.io/calculator.html">the notes</a> if you can't guess how do proceed.</p>

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# (5/9)(-10 - 32)
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# 9/5(100) + 32
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# -4.9\cdot 8^2 + 1.5 \cdot 8 + 1.0
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# \frac{1 + 2\cdot 3}{4 + 5^6}
# $$

# %% [markdown]
# <h2>Math functions</h2>

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# \sqrt{ 0.62 \cdot (1- 0.62 )/100}
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value (here math notation and computer notation are not the same):</p>
# </li>
# </ul>

# %% [markdown]
# $$
# \cos^2(\pi/3)
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# \sin^2(\pi/3)  \cdot \cos((\pi/6)^2)
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# e^{(1/2)\cdot(3 - 2.3 )^2}
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# 1 + \frac{1}{2} + \frac{1}{2\cdot 3} + \frac{1}{2\cdot 3\cdot4} + \frac{1}{2\cdot 3\cdot4\cdot5}
# $$

# %% [markdown]
# <ul>
# <li><p>Compute the following value (<code>cosd</code> takes degree arguments, <code>cos</code> takes radian values):</p>
# </li>
# </ul>

# %% [markdown]
# $$
# \frac{5}{\cos( 50 ^\circ)}  + \frac{8}{\sin( 50 ^\circ)}
# $$

# %% [markdown]
# <ul>
# <li><p>In mathematics a function is defined not only by a rule but also by a <em>domain</em> of possible values. Similarly with <code>Julia</code>. What kind of error does <code>Julia</code> respond with if you try this command: <code>sqrt&#40;-1&#41;</code>?</p>
# </li>
# </ul>

# %% [markdown]
# <h2>Precedence</h2>

# %% [markdown]
# <ul>
# <li><p>There are 5 operations in the following expression. Write a similar expression using 4 pairs of parentheses that evaluates to the same value:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# 1 - 2 + 3 \cdot 4 ^ 5 / 6
# $$

# %% [markdown]
# <ul>
# <li><p>Which of these will also produce $1/(3\cdot4)$:</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; `1 / 3 / 4`
# &#10054; `1 * 3 / 4`
# &#10054; `1 / 3 * 4`

# %% [markdown]
# <h2>Variable</h2>

# %% [markdown]
# <ul>
# <li><p>Let <code>x&#61;6</code> and <code>y&#61;7</code> compute</p>
# </li>
# </ul>

# %% [markdown]
# $$
# x - \sin(x + y)/\cos(x - y)
# $$

# %% [markdown]
# <ul>
# <li><p>For the polynomial</p>
# </li>
# </ul>

# %% [markdown]
# $$
# y = ax^2 + bx + c
# $$

# %% [markdown]
# <p>Let $a=0.00014$, $b=0.61$, $c=649$, and $x=200$. What is $y$?</p>

# %% [markdown]
# <ul>
# <li><p>If</p>
# </li>
# </ul>

# %% [markdown]
# $$
# \frac{\sin(\theta_1)}{v_1} = \frac{\sin(\theta_2)}{v_2}
# $$

# %% [markdown]
# <p>and $\theta_1 = \pi/5$, $\theta_2 = \pi/6$, and $v_1=2$, find $v_2$.</p>

# %% [markdown]
# <h2>Some applications</h2>

# %% [markdown]
# <ul>
# <li><p>The period of simple pendulum depends on a gravitational constant $g=9.8$ and the pendulum length, $L$, in meters, according to the formula: $T=2\pi\sqrt{L/g}$.</p>
# <p>A rope swing is timed to have a period of $6$ seconds. How long is the length of the rope if the formula applies?</p>
# </li>
# </ul>

# %% [markdown]
# <ul>
# <li><p>An object dropped from a building of height $h$ (in feet) will fall according to the laws of projectile motion:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# y(t) = h - 16t^2
# $$

# %% [markdown]
# <p>If $h=53$ find $y$ if $t=1.5$.</p>

# %% [markdown]
# <ul>
# <li><p>Suppose $v = 2\cdot 10^8$ and $c = 3 \cdot 10^8$ compute</p>
# </li>
# </ul>

# %% [markdown]
# $$
# \frac{1}{\sqrt{1 - v^2/c^2}}
# $$

# %% [markdown]
# <p>(Be careful, this expression from a theory of relativity is susceptible to <em>integer</em> overflow on some computers!)</p>

# %% [markdown]
# <h2>Trig practice</h2>

# %% [markdown]
# <ul>
# <li><p>A triangle has sides $a=500$, $b=750$, and $c=901$. Is this a right triangle?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; Yes
# &#10054; No

# %% [markdown]
# <ul>
# <li><p>The law of sines states for a triangle with angle $A$, $B$, and $C$</p>
# </li>
# </ul>

# %% [markdown]
# <p>and opposite sides labeled $a$, $b$, $c$ one has</p>

# %% [markdown]
# $$
# \sin(A)/a = \sin(B)/b = \sin(C)/c.
# $$

# %% [markdown]
# <p>If $A=115^\circ$, $a=123$, and $b=16$, find $B$ (in degrees).</p>

# %% [markdown]
# <ul>
# <li><p>The law of cosines generalizes Pythagorean's theorem: $c^2 = a^2 + b^2 - 2ab \cos(C)$. A triangle has sides $a=5$, $b=9$, and $c=8$. Find the angle $C$ (in radians)</p>
# </li>
# </ul>

# %% [markdown]
# <h2>Numbers</h2>

# %% [markdown]
# <p>Scientific notation represents real numbers as $\pm a \cdot 10^b$, where $b$ is an integer, and $a$ may be a real number in the range $[1.0, 10)$. In <code>Julia</code> such numbers are represented with an <code>e</code> to replace the 10, as with <code>1.2e3</code> which would be $1.2 \cdot 10^3$ (1,230) or <code>3.2e-1</code>, which would be $3.2 \cdot 10^{-1}$ (0.32).</p>

# %% [markdown]
# <ul>
# <li><p>The output of <code>sin&#40;pi&#41;</code> in <code>Julia</code> gives <code>1.2246467991473532e-16</code>. Is this number</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; close to 0
# &#10054; close to 1.22
# &#10054; close to -1.22

# %% [markdown]
# <ul>
# <li><p>Which number is larger? <code>9e-10</code> or <code>7e8</code>?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; `7e8`
# &#10054; `9e-10`

# %% [markdown]
# <ul>
# <li><p>Is <code>7e-10</code>  greater than <code>8e-9</code>?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; Yes
# &#10054; No

# %% [markdown]
# <ul>
# <li><p>Which number is closest to <code>1.23e-4</code>?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; $1000$
# &#10054; $1/10$
# &#10054; $1/1000$
# &#10054; $1/10000$

# %% [markdown]
# <ul>
# <li><p>What is the sum of <code>12e3</code> and <code>32e-1</code>?</p>
# </li>
# </ul>

# %% [markdown]
# <ul>
# <li><p>What is the "standard form" of this number? $3.141\cdot 10^{-2}$?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; 0.003141
# &#10054; 0.03141
# &#10054; 0.3141
# &#10054; 3.141
# &#10054; 31.41
# &#10054; 314.1

# %% [markdown]
# <ul>
# <li><p>After rounding, the speed of light is $c=299,790,000$ in meters per second. Which value expresses this in scientific notation?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; 2.9979e9
# &#10054; 2.9979e8
# &#10054; 2.9979e7
# &#10054; 2.9979e-7
# &#10054; 2.9979e-8
# &#10054; 2.9979e-9

# %% [markdown]
# <ul>
# <li><p>Two fundamental constants of the world are Avogadro's number, <code>6.022e23</code>,  and the Planck constant, <code>6.626e-34</code>. Which is larger?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; Avogadro's number
# &#10054; The Planck constant
