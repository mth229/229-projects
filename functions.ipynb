# %% [markdown]
# <h1>Questions to be handed in for project 2: Functions in Julia</h1>

# %% [markdown]
# <p>Read more about this <a href="http://mth229.github.io/functions.html">here</a>. We begin by loading the <code>MTH229</code> package:</p>

# %%
using MTH229

# %% [markdown]
# <hr />

# %% [markdown]
# <p>For the impatient:</p>

# %% [markdown]
# <p>A <em>function</em> in mathematics is <a href="http://tinyurl.com/c2rwqyb">defined</a> as "a relation between a set of inputs and a set of permissible outputs with the property that each input is related to exactly one output." That is a general definition. Specialized to mathematical functions of one real variable returning a real value, we can define a function in terms of a rule, such as:</p>

# %% [markdown]
# $$
# f(x) = x^2 - 2.
# $$

# %% [markdown]
# <p>The <strong>domain</strong> is the set of all permissible values for $x$, in this case all $x$, but this need not be the case either due to the rule not being defined for some $x$ or a more explicit restriction, such as $x \geq 0$. The <strong>range</strong> is the set of all possible outputs. Written in set notation, this is $\{f(x): x \in \text{ the domain }\}$.</p>

# %% [markdown]
# <p>Mathematically, we evaluate or call a function with the notation $f(2)$ or $f(3)$, say.</p>

# %% [markdown]
# <p>Mathematically we might refer to the function by its name, $f$, or its values $f(2)$, ...</p>

# %% [markdown]
# <p>In <code>Julia</code> basic mathematical  functions are defined and used with the <em>exact</em> same notation. This creates a function <code>f</code>:</p>

# %%
f(x) = x^2 - 2
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Unlike an expression, the value <code>x</code> in is not needed to be defined until we call the function. As with math, this variable name need not be <code>x</code> – it could be <code>y</code> or <code>theta</code> – though it often is.</p>

# %% [markdown]
# <p>We can call <code>f</code> for the value of <code>2</code> with:</p>

# %%
f(2)
# Out:
# 2

# %% [markdown]
# <p>That is, as with typical mathematical notation, the function is "called" by passing a value to it with parentheses.</p>

# %% [markdown]
# <p>Within a cell, we can evaluate one or more values by using commas to separate them:</p>

# %%
f(1), f(2), f(3)
# Out:
# (-1,2,7)

# %% [markdown]
# <p>The function name refers to the function object:</p>

# %%
f
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Don't worry about the words "generic" and "method", but be aware that because of this you can't rename a function into a variable, without an error. As well, <code>Julia</code> isn't even very keen on reusing a function name for another function and may give a warning.</p>

# %% [markdown]
# <p>Functions can be more complicated than the "one-liners" illustrated. In that case, a multiline form is available:</p>

# %%
function fn_name(args...)
  body
end

# %% [markdown]
# <p>The keyword <code>function</code> indicates this is a function whose name is given in the definition. Within the body, the last expression evaluated is the ouput, unless a <code>return</code> statement is used.</p>

# %% [markdown]
# <hr />

# %% [markdown]
# <p>For basic uses of functions – 90% of the uses in this class – the above covers what you need to know about functions.</p>

# %% [markdown]
# <p>However, there are some finer details that do arise from time to time, as explained later on.</p>

# %% [markdown]
# <h3>Questions</h3>

# %% [markdown]
# <ul>
# <li>Define the following function:</li>
# </ul>

# %%
f(x) = exp(-x) * sin(x)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Find the values $f(1)$ and $f(e)$:</p>

# %% [markdown]
# <hr />

# %% [markdown]
# <p>The value of $f(1)$ is:</p>

# %% [markdown]
# <p>The value of $f(e)$ is:</p>

# %% [markdown]
# <ul>
# <li>Define the function</li>
# </ul>

# %%
f(x) = 5/sin(x) + 8/cos(x)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Which value is greater? $f(\pi/6)$ or $f(\pi/3)$?</p>

# %% [markdown]
# &#10054; $f(\pi/6)$
#
# &#10054; $f(\pi/3)$

# %% [markdown]
# <ul>
# <li>Write a function that describes a line with slope $1.5$ going through   the point $(3,1)$. What is the value of $f(10)$?</li>
# </ul>

# %% [markdown]
# <p>The function is:</p>

# %% [markdown]
# <p>The value of $f(10)$ is:</p>

# %% [markdown]
# <ul>
# <li>Write a function to convert Celsius to Fahrenheit $F=9/5 C +   32$. Use it to find the Fahrenheit value when $C=56.7$ and when   $C=-89.2$. (The record high and low temperatures.)</li>
# </ul>

# %% [markdown]
# <p>The function is</p>

# %% [markdown]
# <p>The value at $C=56.7$ is</p>

# %% [markdown]
# <p>The value at $C=-89.2$ is:</p>

# %% [markdown]
# <ul>
# <li>Write a function that computes</li>
# </ul>

# %% [markdown]
# $$
# f(x) = 10x^2 - 3x  - 7 - \frac{1}{x}
# $$

# %% [markdown]
# <p>Use it to find the values of $f(1)$, and $f(3)$.</p>

# %% [markdown]
# <p>The function is defined by:</p>

# %% [markdown]
# <p>The value $f(1)$ is</p>

# %% [markdown]
# <p>The value $f(3)$ is</p>

# %% [markdown]
# <ul>
# <li>Write a function that computes:</li>
# </ul>

# %% [markdown]
# $$
# f(t) = A\sin(Bt - C) + D
# $$

# %% [markdown]
# <p>where $A=3.1$, $B=2\pi/365$, $C=1.35$, and $D=12.12$.</p>

# %% [markdown]
# <p>This function models the amount of daylight in Boston when $t$ records the day of the year. How much daylight is there for $t=1$, $t=365/2$, $t = 35$?</p>

# %% [markdown]
# <p>The function is</p>

# %% [markdown]
# <p>The value at $t=1$ is</p>

# %% [markdown]
# <p>The value at $t=365/2$ is:</p>

# %% [markdown]
# <p>The value at $t=35$ is:</p>

# %% [markdown]
# <ul>
# <li>Person A starts at the origin and moves west at 60 MPH. Person B   starts 200 miles north of the origin and moves south at 70   MPH. Write a function that computes the distance between the two   people as a function of $t$ in minutes.</li>
# </ul>

# %% [markdown]
# <p>(The $(x,y)$ position of person A is $(60\cdot t/60), 0)$ and the $(x,y)$ position of person B is $(0, 200 - 70 \cdot t/60)$. Use the distance formula to write a function.)</p>

# %% [markdown]
# <p>The distance at $t=0$ is:</p>

# %% [markdown]
# <p>The distance at $t=30$ is:</p>

# %% [markdown]
# <p>The distance at $t=120$ is:</p>

# %% [markdown]
# <ul>
# <li>A specific "Norman" window is a square window with a half circle on top. If the length of the side of the square is $x$, write a function describing the total area:</li>
# </ul>

# %% [markdown]
# <p>For such a Norman window with side $x=2$, what is the area?</p>

# %% [markdown]
# <h2>Cases</h2>

# %% [markdown]
# <p>Some functions are defined in terms of cases. For example, a cell phone plan might depend on the data used through:</p>

# %% [markdown]
# <blockquote>
# <p>The amount is 40 dollars for the first 1 Gb  of data, and 10 dollars more for each <em>additional</em> Gb of data.</p>
# </blockquote>

# %% [markdown]
# <p>This function has two cases to consider: one if the data is less than 1 Gb and the other when it is more.</p>

# %% [markdown]
# <p>How to write this in <code>julia</code>?</p>

# %% [markdown]
# <p>The ternary operator <code>predicate ? expression1 : expression2</code> has three pieces: a predicate question, such as <code>x &lt; 10</code> and two expressions, the first is evaluated if the predicate is <code>true</code> and the second if the predicate is <code>false</code>. They are useful to write functions that are defined by cases. (They are a light-weight form of the traditional <code>if-then-else</code> construct.)</p>

# %% [markdown]
# <p>The example above, could then be done with:</p>

# %%
f(d) = d <= 1.0 ? 40.00 : 40.00 + 10.00 * (d - 1.0)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <ul>
# <li>Use the ternary operator to write a function $f(x)$ which takes a   value of $x$ when $x$ is less than 10 and is otherwise a constant   value of 10.</li>
# </ul>

# %% [markdown]
# <ul>
# <li>A function is given by the rule: it is $x^2$ if $x > 1$ and otherwise, $x$.</li>
# </ul>

# %% [markdown]
# <p>Express this in Julia using the ternary operator.</p>

# %% [markdown]
# <ul>
# <li>Write a function to express the following: If a person buys up to   100 units the cost per unit is 5 dollars, for every additional unit   beyond 100 the cost is 4 dollars. The function should return the   total cost to buy $x$ units. (Use the ternary operator with <code>x &lt;&#61;   100</code> as the condition.)</li>
# </ul>

# %% [markdown]
# <h2>Composition</h2>

# %% [markdown]
# <p>Composition of functions is a useful means to break complicated problems into easier to solve ones. The math notation is typically $f(g(x))$ and in <code>julia</code> this is no different. When thinking about the operation of composition, the notation $f \circ g$ is used. For that, there isn't any built-in <code>julia</code> notation.</p>

# %% [markdown]
# <ul>
# <li>For the function $h(x) = ((x+1)/(x-1))^{2/3}$ write this as the   composition of two functions $f(x)$ and $g(x)$. Use these to evaluate   $h(3)$. Show your work and the answer.</li>
# </ul>

# %% [markdown]
# <ul>
# <li>Write the function $h(x) = (\cos(12x))^3$ as the   composition of two functions $f(x)$ and $g(x)$ and use these to evaluate   $h(2)$. Show your work and the answer.</li>
# </ul>

# %% [markdown]
# <h2>Parameters: Functions can have keyword arguments.</h2>

# %% [markdown]
# <p>In the following, we define a function which evaluates a linear equation. A familiar description of a line has two parameters: the slope $m$ and the $y$ intercept, $b$: $y=mx + b$. The main focus is on $x$, but the values of $m$ and $b$ give each problem a different application. To keep these separate, keyword arguments may be given. In the following, <code>m</code> and <code>b</code> are passed in via keywords and, as defined, have default values of <code>m&#61;1</code> and <code>b&#61;0</code>.</p>

# %%
mxplusb(x; m=1, b=0) = m*x + b
mxplusb(10, m=3, b=4)		# arguments are named
# Out:
# 34

# %% [markdown]
# <p>The semicolon separates the two types of arguments.</p>

# %% [markdown]
# <p>If no value are passed, the defaults are used:</p>

# %%
mxplusb(10, m=2)   # evaluates 2 * 10 + 0
# Out:
# 20

# %% [markdown]
# <ul>
# <li>The formula for a <a href="http://en.wikipedia.org/wiki/Catenary">catenary</a> has a parameter $a$:</li>
# </ul>

# %% [markdown]
# $$
# y = a \cosh(x/a)
# $$

# %% [markdown]
# <p>($\cosh(x)$ is the hyperbolic cosine, defined by $(1/2) \cdot (e^x + e^{-x})$ and implemented by <code>cosh</code>.) </p>

# %% [markdown]
# <p>Write a function, <code>c&#40;x;a&#61;1&#41;</code>, with <code>a</code> as a parameter defaulting to $1$. Compute <code>c&#40;1&#41;</code>, <code>c&#40;1,a&#61;2&#41;</code>, and <code>c&#40;1, a&#61;1/2&#41;</code>.</p>

# %% [markdown]
# <p>The function is:</p>

# %% [markdown]
# <p>The value of <code>c&#40;1&#41;</code>:</p>

# %% [markdown]
# <p>The value of <code>c&#40;1, a&#61;2&#41;</code>:</p>

# %% [markdown]
# <p>The value of <code>c&#40;1, a&#61;1/2&#41;</code>:</p>

# %% [markdown]
# <h2>Functions can be used as arguments to other functions:</h2>

# %% [markdown]
# <p>Like many computer languages, <code>Julia</code> allows functions to be arguments to functions. In the following, we see we can plot a function by passing in a function object to a <code>plot</code> function. Notice, the variable name (<code>f</code>) and not the call (<code>f&#40;x&#41;</code>) is given to the <code>plot</code> command (from the <code>Plots</code> package, loaded with <code>MTH229</code>):</p>

# %%
f(x) = sin(pi * x)
plot(f, 0, 2pi)		    # pass function for first argument plot(f,a,b)
# Out:
# Plot(...)

# %% [markdown]
# <p>Using functions in this way will form a <em>very</em> common pattern. </p>

# %% [markdown]
# <h4>Functions can be anonymous.</h4>

# %% [markdown]
# <p>When functions are passed into other functions, it can be convenient to define them without names. The syntax is slightly different, but follows mathematical notation: <code>x -&gt; expression_in_x</code>, or more generally <code>args -&gt; body</code>. Such functions are called <em>anonymous functions</em>:</p>

# %%
plot(x -> sin(x)*cos(2x), 0, 2pi)
# Out:
# Plot(...)

# %% [markdown]
# <h4>Returning a function</h4>

# %% [markdown]
# <p>Familiar mathematical functions take a real number as input and return a real number. However, the concept of a function is more general. With <code>julia</code> it is useful to write functions that take functions as arguments, and return a derived function as an output. For the return value an <em>anonymous function</em> is typically used. </p>

# %% [markdown]
# <ul>
# <li>Describe what the following function does to the argument $f$, when   $f$ is a function. (There isn't anything to do but recognize that   <code>n</code> takes a function as input and returns a function as output, this   question is how is <code>n&#40;f&#41;</code> related to <code>f</code>.)</li>
# </ul>

# %%
n(f::Function) = x -> -f(x)
# Out:
# n (generic function with 1 method)

# %% [markdown]
# <ul>
# <li>This function takes a function and two points and returns a new function that evaluates the secant line:</li>
# </ul>

# %%
function secant(f, a, b)
  m = (f(b) - f(a)) / (b - a)
  x -> f(a) + m * (x - a)
end
# Out:
# secant (generic function with 1 method)

# %% [markdown]
# <p>Let $f(x) = \sin(x)$. Let $a=\pi/6$ and $b=\pi/3$. Show that the secant line at $\pi/4$ is less than the function value at $\pi/4$ by computing both:</p>

# %% [markdown]
# <p>The function at $\pi/4$ is:</p>

# %% [markdown]
# <p>The secant line's value at $\pi/4$ is:</p>

# %% [markdown]
# <hr />

# %% [markdown]
# <h2>Some other facts about functions</h2>

# %% [markdown]
# <h4>Julia functions can have more than one variable</h4>

# %% [markdown]
# <p>For example, this function is used to compute the area of a rectangle:</p>

# %%
rectarea(b, h) = b * h		# area of rectangle is base times height
# Out:
# rectarea (generic function with 1 method)

# %% [markdown]
# <p>The <code>log</code> function is an example, where <code>log&#40;b,x&#41;</code> will find the log base $b$ of $x$, while <code>log&#40;x&#41;</code> uses the default base <code>e</code>, or the natural log.</p>

# %% [markdown]
# <h4>Julia functions with different signatures, can have the same name!</h4>

# %% [markdown]
# <p>This finds the area of a square using the previously defined rectangle function:</p>

# %%
rectarea(b) = rectarea(b,b)	# area of square using area of rectangle
# Out:
# rectarea (generic function with 2 methods)

# %% [markdown]
# <p>Which function is used depends on the arguments that are passed when calling the function. Hence, <code>log&#40;x&#41;</code> will find log base $e$ of $x$ whereas <code>log&#40;10, x&#41;</code> can be used to find log base 10.</p>
