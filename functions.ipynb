# %% [markdown]
# <h1>Questions to be handed in for project 2: Functions in Julia</h1>

# %% [markdown]
# <p>Read more about this <a href="http://mth229.github.io/functions.html">here</a>.</p>

# %% [markdown]
# <p>We begin by loading the <code>MTH229</code> package, which must first be installed:</p>

# %%
using MTH229

# %% [markdown]
# <hr />

# %% [markdown]
# <p>For the impatient:</p>

# %% [markdown]
# <p>A <em>function</em> in mathematics is <a href="http://tinyurl.com/c2rwqyb">defined</a> as "a relation between a set of inputs and a set of permissible outputs with the property that each input is related to exactly one output." That is a general definition. Specialized to mathematical functions of one real variable returning a real value, we can define a function in terms of a rule–-what happens to $x$ to produce $y$, such as this one which squares $x$ then subtracts $2$:</p>

# %% [markdown]
# $$
# f(x) = x^2 - 2.
# $$

# %% [markdown]
# <p>The <strong>domain</strong> of a function is the set of all permissible values for $x$, in this example this is all $x$, but this need not be the case either due to the rule not being defined for some $x$ or a more explicit restriction, such as $x \geq 0$. The <strong>range</strong> is the set of all possible outputs. Written in set notation, this is $\{f(x): x \in \text{ the domain }\}$.</p>

# %% [markdown]
# <p>Mathematically, we evaluate or <strong>call</strong> a function with the notation $f(2)$ or $f(3)$, say.</p>

# %% [markdown]
# <p>Mathematically we might refer to the function by its name, $f$, or its values such as $f(2)$ or $f(\pi)$.</p>

# %% [markdown]
# <p>In <code>Julia</code> basic mathematical functions are defined and used with the <em>exact</em> same notation, save for accommodations in translating math to <code>Julia</code>.</p>

# %% [markdown]
# <p>For example, this command creates a function <code>f</code>:</p>

# %%
f(x) = x^2 - 2
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Unlike an expression, the value <code>x</code> in the definition of <code>f&#40;x&#41;</code> does not need to be defined until the function is actually called. As with math, this variable name need not be <code>x</code> – it could be <code>t</code>, <code>y</code>, <code>theta</code>, or any other valid name.</p>

# %% [markdown]
# <p>We <em>call</em> <code>f</code> for the given value using the same <code>f&#40;x&#41;</code> notation. For example, finding our <code>f</code> at the value of <code>2</code> is done with:</p>

# %%
f(2)
# Out:
# 2

# %% [markdown]
# <p>That is, as with typical mathematical notation, the function is "called" by passing a value to it with parentheses.</p>

# %% [markdown]
# <p>Within a cell, we can evaluate one or more values by using commas to separate them:</p>

# %%
f(1), f(2), f(3)
# Out:
# (-1, 2, 7)

# %% [markdown]
# <p>The function name refers to the function object:</p>

# %%
f
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Don't worry about the words "generic" and "method", but be aware that because of this once you have defined a name as a variable it can not be re-purposed as a function name and vice versa. (In the common first case, read the error message, it will say something like: <code>ERROR: cannot define function a; it already has a value</code>.)</p>

# %% [markdown]
# <p>The "domain" of a <code>Julia</code> function is similar in meaning. <code>Julia</code> may respond with different values, such as <code>Inf</code>, for infinity; <code>NaN</code>, when an expression is indeterminate; or it may throw an error, typically a <code>DomainError</code>:</p>

# %%
f(x) = sqrt(x)/(x*(1-x))
f(1), f(0)
# Out:
# (Inf, NaN)

# %% [markdown]
# <p>and an error with:</p>

# %%
f(-1)
# Out:
# DomainError()

# %% [markdown]
# <p>Functions can be more complicated than the "one-liners" illustrated. In that case, a multiline form is available:</p>

# %%
function fn_name(args...)
  body
end

# %% [markdown]
# <p>The keyword <code>function</code> indicates this is a function whose name is given in the definition. Within the body, the last expression evaluated is the output, unless a <code>return</code> statement is used.</p>

# %% [markdown]
# <hr />

# %% [markdown]
# <p>For basic uses of functions–-90 percent of the uses in this class–-the above covers what you need to know about functions.</p>

# %% [markdown]
# <h3>Questions</h3>

# %% [markdown]
# <ul>
# <li><p>Define the following function:</p>
# </li>
# </ul>

# %%
f(x) = exp(-x) * sin(x)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Find the values $f(1)$ and $f(e)$:</p>

# %% [markdown]
# <hr />

# %% [markdown]
# <p>The value of $f(1)$ is:</p>

# %% [markdown]
# <p>The value of $f(e)$ is:</p>

# %% [markdown]
# <ul>
# <li><p>Define the function</p>
# </li>
# </ul>

# %%
f(x) = 4/sin(x) + 7/cos(x)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>Which value is greater? $f(\pi/6)$ or $f(\pi/3)$?</p>

# %% [markdown]
# &#10054; $f(\pi/3)$
#
# &#10054; $f(\pi/6)$

# %% [markdown]
# <ul>
# <li><p>Write a function to convert Celsius to Fahrenheit $F=9/5 C + 32$. Use it to find the Fahrenheit value when $C=56.7$ and when $C=-89.2$. (The record high and low temperatures.)</p>
# </li>
# </ul>

# %% [markdown]
# <p>The function is</p>

# %% [markdown]
# &#10054; `f(x) = 9/5*x+32`
#
# &#10054; `f(x) = 9/5x+32`
#
# &#10054; `f(x) = 9/5c + 32`
#
# &#10054; `f(x) = 9/5*(x + 32)`

# %% [markdown]
# <p>The value at $C=56.7$ is</p>

# %% [markdown]
# <p>The value at $C=-89.2$ is:</p>

# %% [markdown]
# <ul>
# <li><p>Write a function that describes a line with slope $3.5$ going through the point $(1,1)$. What is the value of $f(10)$?</p>
# </li>
# </ul>

# %% [markdown]
# <p>The function is:</p>

# %% [markdown]
# &#10054; `f(x) = 1+3.5*x`
#
# &#10054; `f(x) = 1+3.5*x-1`
#
# &#10054; `f(x) = 1+3.5*(x-1)`

# %% [markdown]
# <p>The value of $f(10)$ is:</p>

# %% [markdown]
# <ul>
# <li><p>Write a function that computes</p>
# </li>
# </ul>

# %% [markdown]
# $$
# f(x) = 4x^2 - 3x  - 7 - \frac{1}{x}
# $$

# %% [markdown]
# <p>Use it to find the values of $f(1)$, and $f(3)$.</p>

# %% [markdown]
# <p>The function is defined by:</p>

# %% [markdown]
# <p>The value $f(1)$ is</p>

# %% [markdown]
# <p>The value $f(3)$ is</p>

# %% [markdown]
# <hr />

# %% [markdown]
# <p>Functions can have parameters, such as $f(x) = m*x + b$ to describe a line in point slope form. We can define functions with parameters:</p>

# %%
f(x) = m*x + b
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <p>The values assigned to <code>m</code> and <code>b</code> when the function is <em>called</em> will be used for the evaluation. If none are assigned, an undefined variable error will be thrown.</p>

# %% [markdown]
# <ul>
# <li><p>Write a function that computes:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# f(t) = A\sin(Bt - C) + D
# $$

# %% [markdown]
# <p>where $A=3.1$, $B=2\pi/365$, $C=1.35$, and $D=12.12$.</p>

# %% [markdown]
# <p>This function models the amount of daylight in Boston when $t$ records the day of the year. How much daylight is there for $t=1$, $t=365/2$, $t = 35$?</p>

# %% [markdown]
# <p>The function is</p>

# %% [markdown]
# <p>The value at $t=1$ is</p>

# %% [markdown]
# <p>The value at $t=365/2$ is:</p>

# %% [markdown]
# <p>The value at $t=35$ is:</p>

# %% [markdown]
# <ul>
# <li><p>Person A starts at the origin and moves west at 60 MPH. Person B starts 200 miles north of the origin and moves south at 70 MPH. Write a function that computes the distance between the two people as a function of $t$ in minutes.</p>
# </li>
# </ul>

# %% [markdown]
# <p>(The $(x,y)$ position of person A is $(60\cdot t/60), 0)$ and the $(x,y)$ position of person B is $(0, 200 - 70 \cdot t/60)$. Use the distance formula to write a function.)</p>

# %% [markdown]
# <hr />

# %% [markdown]
# <p>Which of these defines the appropriate function?</p>

# %% [markdown]
# &#10054; `d(t) = (60t/60 - 0)^2 + (0 - (200 - 70t/60))^2`
#
# &#10054; `d(t) = sqrt( (60t/60 - 0)^2 + (0 - (200 - 70t/60))^2)`
#
# &#10054; `d(t)= sqrt(t^2 - (200 - 70t/60)^2)`

# %% [markdown]
# <p>The distance at $t=0$ is:</p>

# %% [markdown]
# <p>The distance at $t=30$ is:</p>

# %% [markdown]
# <p>The distance at $t=120$ is:</p>

# %% [markdown]
# <ul>
# <li><p>A specific "Norman" window is a square window with a half circle on top. If the length of the side of the square is $x$ Which function describes the total area as a function of the length of one side of the square part?</p>
# </li>
# </ul>

# %% [markdown]
# &#10054; `area(x) = x^2 + pi * r^2`
#
# &#10054; `area(x) = x^2 + 1/2 * pi * (x/2)^2`
#
# &#10054; `area(x) = 1/2 * pi * (x/2)^2`
#
# &#10054; `area(x) = x^2`

# %% [markdown]
# <p>For such a Norman window with side $x=2$, what is the area?</p>

# %% [markdown]
# <h2>Cases</h2>

# %% [markdown]
# <p>Some functions are defined in terms of cases. For example, a cell phone plan might depend on the data used through:</p>

# %% [markdown]
# <blockquote>
# <p>The amount is 40 dollars for the first 1 Gb  of data, and 10 dollars more for each <em>additional</em> Gb of data.</p>
# </blockquote>

# %% [markdown]
# <p>This function has two cases to consider: one if the data is less than 1 Gb and the other when it is more.</p>

# %% [markdown]
# <p>How to write this in <code>Julia</code>?</p>

# %% [markdown]
# <p>The ternary operator <code>predicate ? expression1 : expression2</code> has three pieces: a predicate question, such as <code>x &lt; 10</code> and two expressions, the first is evaluated if the predicate is <code>true</code> and the second if the predicate is <code>false</code>. Using the ternary operator, simple case-like functions can be defined in one line.</p>

# %% [markdown]
# <p>For example, the above can be defined in <code>Julia</code> with:</p>

# %%
f(d) = d <= 1.0 ? 40.00 : 40.00 + 10.00 * (d - 1.0)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# <ul>
# <li><p>Use the ternary operator to write a function $f(x)$ which takes a value of $x$ when $x$ is less than 10 and is otherwise a constant value of 10.</p>
# </li>
# </ul>

# %% [markdown]
# <ul>
# <li><p>A function is given by the rule: it is $x^2$ if $x > 1$ and otherwise, $x$.</p>
# </li>
# </ul>

# %% [markdown]
# <p>Express this in Julia using the ternary operator.</p>

# %% [markdown]
# <ul>
# <li><p>Write a function to express the following: If a person buys up to 100 units the cost per unit is 5 dollars, for every additional unit beyond 100 the cost is 4 dollars. The function should return the total cost to buy $x$ units. (Use the ternary operator with <code>x &lt;&#61; 100</code> as the condition.)</p>
# </li>
# </ul>

# %% [markdown]
# <p>The ternary operator is  a light-weight form of the traditional <code>if-then-else</code> construct. For those familiar with this construct, or for more complicated expressions, in <code>Julia</code> this construct is written as:</p>

# %%
if logical_expression
  do_something
elseif another_logical_expression
  do_something_else
else
  do_this_if_all_else_fails
end

# %% [markdown]
# <p>There can be zero, one, or more than one <code>elseif</code> command and the <code>else</code> is optional. Here we use this form to recreate the "sign" function which is either $-1$, $0$, or $1$ depending on the sign o $x$:</p>

# %%
sgn(x) = if x < 0
   -1
elseif x > 0
    1
else
    0
end
# Out:
# sgn (generic function with 1 method)

# %% [markdown]
# <p>To see, we have:</p>

# %%
sgn(-pi), sgn(0), sgn(e)
# Out:
# (-1, 0, 1)

# %% [markdown]
# <ul>
# <li><p>We want a function <code>trim</code> that computes $f(x)$ and if that value is greater than $10$, it returns $10$; if less than $-10$, it returns $-10$; otherwise it returns the value $f(x)$.</p>
# </li>
# </ul>

# %% [markdown]
# <p>Will this function work for this task?</p>

# %%
trim(x) = if x > 10
    10
elseif x < -10
    -10
else
    f(x)
end
# Out:
# trim (generic function with 1 method)

# %% [markdown]
# &#10054; Yes
#
# &#10054; No

# %% [markdown]
# <p>Will this function work for this task?</p>

# %%
trim(x) = if f(x) > 10
    10
elseif f(x) < -10
    -10
else
    f(x)
end
# Out:
# trim (generic function with 1 method)

# %% [markdown]
# &#10054; Yes
#
# &#10054; No

# %% [markdown]
# <h2>Composition</h2>

# %% [markdown]
# <p>Composition of functions is a useful means to break complicated problems into easier to solve ones. The math notation is typically $f(g(x))$ and in <code>Julia</code> this is no different.</p>

# %% [markdown]
# <ul>
# <li><p>We can express the function $h(x) = ((x+1)/(x-1))^{2/3}$   as a composition of two functions $f(x)$ and $g(x)$?</p>
# </li>
# </ul>

# %% [markdown]
# <p>Does this composition work:</p>

# %%
f(x) = (x+1) / (x-1)
g(x) = x^(2/3)
h(x) = f(g(x))
# Out:
# h (generic function with 1 method)

# %% [markdown]
# &#10054; Yes
#
# &#10054; No

# %% [markdown]
# <p>Does this composition work:</p>

# %%
f(x) = x^(2/3)
g(x) = (x+1) / (x-1)
h(x) = f(g(x))
# Out:
# h (generic function with 1 method)

# %% [markdown]
# &#10054; Yes
#
# &#10054; No

# %% [markdown]
# <p>Using the right composition, find the value of $h(3)$. </p>

# %% [markdown]
# <ul>
# <li><p>It is common to express the composition $h(x) = f(g(x))$ in terms of an "outer" function $f$ and an "inner" function $g$.</p>
# </li>
# </ul>

# %% [markdown]
# <p>What is an "outer" function if $h(x) = \sqrt{x^2 - 2}$ is expressed as a composition using <code>Julia</code>:</p>

# %% [markdown]
# &#10054; `f(x) = x^2 - 2`
#
# &#10054; `f(x) = sqrt(x)`
#
# &#10054; `f(x) = x^2`

# %% [markdown]
# <p>What is an "inner" function if $h(x) =\sin^2(x^2 - 2)$ is expressed as a composition using <code>Julia</code>:</p>

# %% [markdown]
# &#10054; `g(x) = sin(x)`
#
# &#10054; `g(x) = x^2`
#
# &#10054; `g(x) = x^2 - 2`

# %% [markdown]
# <h2>Functions may need more than one argument</h2>

# %% [markdown]
# <p>In <code>Julia</code> some functions require more than one argument. There are two ways that a function can distinguish between arguments:</p>

# %% [markdown]
# <p><strong>Using position</strong>. A typical case is the function expressing the $\log$ of $x$ base $b$. The function must have both a position to pass in values for either $x$ or $b$. In <code>Julia</code> the function is written <code>log&#40;b, x&#41;</code>:</p>

# %%
b, x = 5, 100
a = log(b, x)
b^a - x  # verify, is this close to 0?
# Out:
# 8.526512829121202e-14

# %% [markdown]
# <p>(This also shows that <code>Julia</code> can have the same name for <strong>different</strong> functions, as <code>log&#40;x&#41;</code> does the logarithm base $e$ and takes only 1 argument.)</p>

# %% [markdown]
# <p><strong>Using keyword names</strong>. Some arguments can be designated by a "keyword", which can have default values. This is common in general, but not so much used within these notes. This style provides a natural means to pass <em>parameters</em> to a function.</p>

# %% [markdown]
# <p>This example shows how to define a <code>Log</code> function that can use a keyword name with a default value:</p>

# %%
Log(x; b=e) = log(b, x)
# Out:
# Log (generic function with 1 method)

# %% [markdown]
# <p>Then <code>Log&#40;100&#41;</code> will find <code>log&#40;e, 100&#41;</code> and calling <code>Log&#40;100, b&#61;5&#41;</code> will find $\log_5(100)$:</p>

# %%
Log(100), Log(100, b=5)
# Out:
# (4.605170185988092, 2.8613531161467867)

# %% [markdown]
# <hr />

# %% [markdown]
# <ul>
# <li><p>The apparent magnitude of a celestial object is reported on a logarithmic scale by the following formula $m=-5\log_{100}(F/F_0)$. Suppose an object has $F=4.8\cdot 10^{10}$ and we take $F_0=1$. Using the two-argument form of <code>log</code> find <code>m</code>:</p>
# </li>
# </ul>

# %% [markdown]
# <ul>
# <li><p>An integer $n$ modulo $k$ ($n,k > 0$) is defined to be the remainder, $0 \leq r < k$, after division of $n$ by $k$. It is implemented in <code>Julia</code> with <code>mod&#40;n, k&#41;</code>.</p>
# </li>
# </ul>

# %% [markdown]
# <p>Using <code>mod</code>, find  <code>87654321</code> modulo <code>12345678</code>.</p>

# %% [markdown]
# <ul>
# <li><p>Define the function to find a point on a line in slope-intercept form, as follows:</p>
# </li>
# </ul>

# %%
mxplusb(x; m=1, b=0) = m*x + b
# Out:
# mxplusb (generic function with 1 method)

# %% [markdown]
# <p>Using the <em>default</em> values for $m$ and $b$, what is the value at $x=10$?</p>

# %% [markdown]
# <p>The conversion of Celsius into Fahrenheit follows the equation $C = 5/9 F - 160/9$. Using <code>mxplusb</code>, find the temperature in Celsius when Fahrenheit is 90.</p>

# %% [markdown]
# <ul>
# <li><p>The formula for a <a href="http://en.wikipedia.org/wiki/Catenary">catenary</a> has a parameter $a$:</p>
# </li>
# </ul>

# %% [markdown]
# $$
# y = a \cosh(x/a)
# $$

# %% [markdown]
# <p>($\cosh(x)$ is the hyperbolic cosine, defined by $(1/2) \cdot (e^x + e^{-x})$ and implemented in <code>Julia</code> by <code>cosh</code>.) </p>

# %% [markdown]
# <p>Our function for this could be:</p>

# %%
c(x; a = 1) = a * cosh(x/a)
# Out:
# c (generic function with 1 method)

# %% [markdown]
# <p>Find the value of <code>c&#40;1&#41;</code>:</p>

# %% [markdown]
# <p>Find the value of <code>c&#40;1, a&#61;2&#41;</code>:</p>

# %% [markdown]
# <h2>Functions can be used as arguments to other functions:</h2>

# %% [markdown]
# <p>Calculus has three main operations: The limit of a <em>function</em>, the derivative of a <em>function</em>, and the integral of a <em>function</em>.  These operations take a function and compute some value. For limits this value is a number, for derivatives this value is another function. In <code>Julia</code> we will use functions to implement each. </p>

# %% [markdown]
# <p>Using <code>Julia</code> operations on functions are just functions where the <em>arguments</em> are themselves functions and, <em>possibly</em>, the return value is also a function.</p>

# %% [markdown]
# <p>The first example we will encounter is related to plotting. The details come another day, but here is the pattern to make a plot (assuming the <code>MTH229</code> package has been loaded):</p>

# %%
f(x) = sin(x^2)
plot(f, 0, pi)
# Out:
# Plot(...)

# %% [markdown]
# <p>The first argument to <code>plot</code> is a function object–not a function call, as in <code>f&#40;x&#41;</code>, the second and third describe an interval to plot over. This will be a typical pattern: <code>someaction&#40;f, arguments...&#41;</code>.</p>

# %% [markdown]
# <ul>
# <li><p>The <code>MTH229</code> package defines a function <code>tangent</code> that returns a function describing the tangent line to a function at $x=c$. For example, these commands define a function <code>tl</code> that represents the tangent line to $f(x) = \sin(x)$ at $x=\pi/4$:</p>
# </li>
# </ul>

# %%
f(x) = sin(x)
tl(x) = tangent(f, pi/4)(x)  # notice (x) on both sides of the equals sign
# Out:
# tl (generic function with 1 method)

# %% [markdown]
# <p>The tangent line has the from $y=mx+b$. Use <code>tl</code> above to find $b$:</p>

# %% [markdown]
# <p>Now use <code>tl</code> to find $m$:</p>
